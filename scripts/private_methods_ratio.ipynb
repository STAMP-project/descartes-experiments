# %% [markdown]
# This notebook shows the ratio of private methods in pseudo-tested methods, the set of methods under analysis and all the methods for each project.

# %%
# %matplotlib inline

# %%
from private_methods_ratio import get_data, table, plot
from tables import IPythonTableBuilder

# %%
data = list(get_data())

# %%
table(data, build_table=IPythonTableBuilder)
# Out:
# <table><tr><th>Project</th><th style="text-align:right">Pseudo-tested</th><th style="text-align:right">Under analysis</th><th style="text-align:right">All methods</th></tr><tr><td>AuthZForce PDP Core</td><td>0.6923076923076923</td><td>0.6907216494845361</td><td>0.7161862527716186</td></tr><tr><td>Amazon Web Services SDK</td><td>0.38839285714285715</td><td>0.3888888888888889</td><td>0.10518129243965041</td></tr><tr><td>Apache Commons CLI</td><td>0.5</td><td>0.2765957446808511</td><td>0.22602739726027396</td></tr><tr><td>Apache Commons Codec</td><td>0.75</td><td>0.2981220657276995</td><td>0.3398328690807799</td></tr><tr><td>Apache Commons Collections</td><td>0.3</td><td>0.1444805194805195</td><td>0.28205128205128205</td></tr><tr><td>Apache Commons IO</td><td>0.10344827586206896</td><td>0.12480499219968799</td><td>0.11784511784511785</td></tr><tr><td>Apache Commons Lang</td><td>0.40425531914893614</td><td>0.14769719428268926</td><td>0.2112676056338028</td></tr><tr><td>Apache Flink</td><
# ...

# %%
plot(data)
